# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohit-Munda/GenAIWorkshop/blob/main/Workshop-1/Day-1/PredictScoresRegresion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Predict exam scores based on hours of study using Linear Regression

# %% [markdown]
# # Step 1: Load Required Python Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %% [markdown]
# # Step 2: Load Data

# %%
# Sample data (Hours studied vs Exam score)
# X = Hours studied, y = Exam score
X = np.array([[1], [2], [3], [4], [5], [6]])  # Independent variable
y = np.array([35, 45, 50, 60, 65, 75])       # Dependent variable

# %% [markdown]
# # Step 3: Exploratory Data Analysis

# %%
plt.plot(X,y)
plt.xlabel('Hours Studied')
plt.ylabel('Exam Score')
plt.title('Hours Studied vs Exam Scores')
plt.grid(True)
plt.show()

# %% [markdown]
# # Step 4: Model Training

# %%
# Create and train the model
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# # Step 5: Model Predictions

# %%
# Make a prediction
hours_studied = [[7]]
predicted_score = model.predict(hours_studied)
print(f"Predicted exam score for studying {hours_studied[0][0]} hours: {predicted_score[0]:.2f}")
# Out:
# Predicted exam score for studying 7 hours: 82.00

# %%
# Visualize the data and regression line
plt.scatter(X, y, color='blue', label='Actual Data')
plt.plot(X, model.predict(X), color='red', label='Regression Line')
plt.scatter(hours_studied, predicted_score, color='green', label='Prediction')
plt.xlabel('Hours Studied')
plt.ylabel('Exam Score')
plt.title('Simple Linear Regression')
plt.legend()
plt.grid(True)
plt.show()
